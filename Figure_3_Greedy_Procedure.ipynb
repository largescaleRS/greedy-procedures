# %%
import numpy as np
import ray
import matplotlib.pyplot as plt
import time
from utils import *
from procedures import *

plt.rcParams["font.sans-serif"] = "DejaVu Sans"
plt.rcParams["mathtext.default"]  = "it"
plt.rcParams["mathtext.fontset"]  = "dejavusans"

# %%
# Number of parallel threads to be used
# Shut down any existing Ray processes
# Initialize Ray with the specified number of parallel threads


num_cpus=96
ray.shutdown()
ray.init(num_cpus=num_cpus, ignore_reinit_error=True)
# Out:
# 2022-12-10 09:48:19,318	INFO services.py:1274 -- View the Ray dashboard at http://127.0.0.1:8265
# {'node_ip_address': '10.192.9.221',
#  'raylet_ip_address': '10.192.9.221',
#  'redis_address': '10.192.9.221:6379',
#  'object_store_address': 'tcp://127.0.0.1:51720',
#  'raylet_socket_name': 'tcp://127.0.0.1:56755',
#  'webui_url': '127.0.0.1:8265',
#  'session_dir': 'C:\\Users\\Admin\\AppData\\Local\\Temp\\ray\\session_2022-12-10_09-48-07_940520_12296',
#  'metrics_export_port': 61031,
#  'node_id': '133328cbd6fa1cb2d751e11adf9f8b9eaa81e3ed5e7ee84694324856'}

# %% [raw]
# The experiments included are all conducted on lab servers with more than 50 CPU cores (supporting more than 100 concurrent computing threads) and 512 GB memory.
#
# Even if your PC or server does not have 48 CPUs to support 96 parallel threads (Ray actors), you CAN also run the codes. But, when running the computing blocks, the warning of too many actors may appear. You can ignore the warnings and wait for the completed results. The total computing time depends on how many CPUs are TRULY used and the performance of your CPUs. It may take HOURS to finish one single experiment if you only have 8 CPUs on your computer. A 512 GB of memory is NOT necessary, but there is a risk of memory overload if it is too small.
#
# You CAN change the num_cpus (16 if there are 8 CPUs) to a smaller number to avoid the warnings or overload of your computer.
#
# You may change the n_replications in the following to a smaller number to shorten the total time, but the final results WILL change!

# %%
seed = 20232023
np.random.seed(seed)
n_replications =1000
 
min_power = 2
max_power = 16
base = 2

gamma = 0.1
var = 1
lamda = -1
varlow = 1
varhigh = 2

rng = np.random.default_rng(seed)

# %% [raw]
# The PCS results of Greedy procedure will be used in Figure_3.ipynb for producing the Figure 3

# %%
Greedy_results =  []
for power in np.arange(min_power, max_power+1):
    
    print("This problem has {} alternatives".format(base**power))
    SCCVgenerators =  [SCCVGenerator(base**power, gamma, var) for i in range(n_replications)]
    EMCVgenerators =   [EMCVGenerator(base**power, gamma, lamda, var) for i in range(n_replications)]
    EMIVgenerators =  [EMIVGenerator(base**power, gamma, lamda, varlow, varhigh) for i in range(n_replications)]
    EMDVgenerators =  [EMDVGenerator(base**power, gamma, lamda, varlow, varhigh) for i in range(n_replications)]
    
    generator_types = [SCCVgenerators, EMCVgenerators,  EMIVgenerators, EMDVgenerators]
    
    for i, generators in enumerate(generator_types):
        print("----------------------------------Generator Type {}--------------------------------".format(i))
        n0 = 1
        ng = 99
        print("Greedy")
        PCS, PGS = parallel_experiments(rng,  generators, policy=EFG, remote_policy=remote_EFG,args={"n0":n0, "ng":ng})
        Greedy_results.append(PCS)
Greedy_results
# Out:
# This problem has 4 alternatives
# ----------------------------------Generator Type 0--------------------------------
# Greedy
# --------New experiments with  k=4----------------------
# Start to simulate... at Sat Dec 10 09:48:24 2022
# PCS:0.368, PGS:0.368
# Total time used: 0.8133480548858643s, simulation ends at Sat Dec 10 09:48:24 2022
# ----------------------------------Generator Type 1--------------------------------
# Greedy
# --------New experiments with  k=4----------------------
# Start to simulate... at Sat Dec 10 09:48:25 2022
# PCS:0.681, PGS:0.681
# Total time used: 0.6952340602874756s, simulation ends at Sat Dec 10 09:48:25 2022
# ----------------------------------Generator Type 2--------------------------------
# Greedy
# --------New experiments with  k=4----------------------
# Start to simulate... at Sat Dec 10 09:48:26 2022
# PCS:0.659, PGS:0.659
# Total time used: 0.7313127517700195s, simulation ends at Sat Dec 10 09:48:26 2022
# ----------------------------------Generator Type 3--------------------------------
# Greedy
# --------New experiments with  k=4----------------------
# Start to simulate... at Sat Dec 10 09:48:26 2022
# PCS:0.574, PGS:0.574
# Total time used: 0.7810418605804443s, simulation ends at Sat Dec 10 09:48:26 2022
# This problem has 8 alternatives
# ----------------------------------Generator Type 0--------------------------------
# Greedy
# --------New experiments with  k=8----------------------
# Start to simulate... at Sat Dec 10 09:48:27 2022
# PCS:0.253, PGS:0.253
# Total time used: 0.7439897060394287s, simulation ends at Sat Dec 10 09:48:27 2022
# ----------------------------------Generator Type 1--------------------------------
# Greedy
# --------New experiments with  k=8----------------------
# Start to simulate... at Sat Dec 10 09:48:28 2022
# PCS:0.552, PGS:0.552
# Total time used: 0.8229701519012451s, simulation ends at Sat Dec 10 09:48:28 2022
# ----------------------------------Generator Type 2--------------------------------
# Greedy
# --------New experiments with  k=8----------------------
# Start to simulate... at Sat Dec 10 09:48:29 2022
# PCS:0.565, PGS:0.565
# Total time used: 0.7966434955596924s, simulation ends at Sat Dec 10 09:48:29 2022
# ----------------------------------Generator Type 3--------------------------------
# Greedy
# --------New experiments with  k=8----------------------
# Start to simulate... at Sat Dec 10 09:48:30 2022
# PCS:0.432, PGS:0.432
# Total time used: 0.7937188148498535s, simulation ends at Sat Dec 10 09:48:30 2022
# This problem has 16 alternatives
# ----------------------------------Generator Type 0--------------------------------
# Greedy
# --------New experiments with  k=16----------------------
# Start to simulate... at Sat Dec 10 09:48:30 2022
# PCS:0.188, PGS:0.188
# Total time used: 0.7732391357421875s, simulation ends at Sat Dec 10 09:48:30 2022
# ----------------------------------Generator Type 1--------------------------------
# Greedy
# --------New experiments with  k=16----------------------
# Start to simulate... at Sat Dec 10 09:48:31 2022
# PCS:0.46, PGS:0.46
# Total time used: 0.7781171798706055s, simulation ends at Sat Dec 10 09:48:31 2022
# ----------------------------------Generator Type 2--------------------------------
# Greedy
# --------New experiments with  k=16----------------------
# Start to simulate... at Sat Dec 10 09:48:32 2022
# PCS:0.436, PGS:0.436
# Total time used: 0.7361884117126465s, simulation ends at Sat Dec 10 09:48:32 2022
# ----------------------------------Generator Type 3--------------------------------
# Greedy
# --------New experiments with  k=16----------------------
# Start to simulate... at Sat Dec 10 09:48:33 2022
# PCS:0.327, PGS:0.327
# Total time used: 0.7781167030334473s, simulation ends at Sat Dec 10 09:48:33 2022
# This problem has 32 alternatives
# ----------------------------------Generator Type 0--------------------------------
# Greedy
# --------New experiments with  k=32----------------------
# Start to simulate... at Sat Dec 10 09:48:34 2022
# PCS:0.128, PGS:0.128
# Total time used: 1.029689073562622s, simulation ends at Sat Dec 10 09:48:34 2022
# ----------------------------------Generator Type 1--------------------------------
# Greedy
# --------New experiments with  k=32----------------------
# Start to simulate... at Sat Dec 10 09:48:35 2022
# PCS:0.386, PGS:0.386
# Total time used: 1.0599157810211182s, simulation ends at Sat Dec 10 09:48:35 2022
# ----------------------------------Generator Type 2--------------------------------
# Greedy
# --------New experiments with  k=32----------------------
# Start to simulate... at Sat Dec 10 09:48:36 2022
# PCS:0.353, PGS:0.353
# Total time used: 1.0267655849456787s, simulation ends at Sat Dec 10 09:48:36 2022
# ----------------------------------Generator Type 3--------------------------------
# Greedy
# --------New experiments with  k=32----------------------
# Start to simulate... at Sat Dec 10 09:48:37 2022
# PCS:0.29, PGS:0.29
# Total time used: 1.0287115573883057s, simulation ends at Sat Dec 10 09:48:37 2022
# This problem has 64 alternatives
# ----------------------------------Generator Type 0--------------------------------
# Greedy
# --------New experiments with  k=64----------------------
# Start to simulate... at Sat Dec 10 09:48:38 2022
# PCS:0.122, PGS:0.122
# Total time used: 1.7102997303009033s, simulation ends at Sat Dec 10 09:48:39 2022
# ----------------------------------Generator Type 1--------------------------------
# Greedy
# --------New experiments with  k=64----------------------
# Start to simulate... at Sat Dec 10 09:48:40 2022
# PCS:0.295, PGS:0.295
# Total time used: 1.6956684589385986s, simulation ends at Sat Dec 10 09:48:40 2022
# ----------------------------------Generator Type 2--------------------------------
# Greedy
# --------New experiments with  k=64----------------------
# Start to simulate... at Sat Dec 10 09:48:42 2022
# PCS:0.29, PGS:0.29
# Total time used: 1.7180981636047363s, simulation ends at Sat Dec 10 09:48:42 2022
# ----------------------------------Generator Type 3--------------------------------
# Greedy
# --------New experiments with  k=64----------------------
# Start to simulate... at Sat Dec 10 09:48:43 2022
# PCS:0.227, PGS:0.227
# Total time used: 1.7122468948364258s, simulation ends at Sat Dec 10 09:48:44 2022
# This problem has 128 alternatives
# ----------------------------------Generator Type 0--------------------------------
# Greedy
# --------New experiments with  k=128----------------------
# Start to simulate... at Sat Dec 10 09:48:45 2022
# PCS:0.134, PGS:0.134
# Total time used: 3.350388288497925s, simulation ends at Sat Dec 10 09:48:47 2022
# ----------------------------------Generator Type 1--------------------------------
# Greedy
# --------New experiments with  k=128----------------------
# Start to simulate... at Sat Dec 10 09:48:48 2022
# PCS:0.256, PGS:0.256
# Total time used: 3.3201613426208496s, simulation ends at Sat Dec 10 09:48:51 2022
# ----------------------------------Generator Type 2--------------------------------
# Greedy
# --------New experiments with  k=128----------------------
# Start to simulate... at Sat Dec 10 09:48:52 2022
# PCS:0.262, PGS:0.262
# Total time used: 3.3567607402801514s, simulation ends at Sat Dec 10 09:48:54 2022
# ----------------------------------Generator Type 3--------------------------------
# Greedy
# --------New experiments with  k=128----------------------
# Start to simulate... at Sat Dec 10 09:48:55 2022
# PCS:0.198, PGS:0.198
# Total time used: 3.3201584815979004s, simulation ends at Sat Dec 10 09:48:57 2022
# This problem has 256 alternatives
# ----------------------------------Generator Type 0--------------------------------
# Greedy
# --------New experiments with  k=256----------------------
# Start to simulate... at Sat Dec 10 09:48:59 2022
# PCS:0.132, PGS:0.132
# Total time used: 6.574993371963501s, simulation ends at Sat Dec 10 09:49:04 2022
# ----------------------------------Generator Type 1--------------------------------
# Greedy
# --------New experiments with  k=256----------------------
# Start to simulate... at Sat Dec 10 09:49:05 2022
# PCS:0.179, PGS:0.179
# Total time used: 6.5593883991241455s, simulation ends at Sat Dec 10 09:49:10 2022
# ----------------------------------Generator Type 2--------------------------------
# Greedy
# --------New experiments with  k=256----------------------
# Start to simulate... at Sat Dec 10 09:49:12 2022
# PCS:0.208, PGS:0.208
# Total time used: 6.563290119171143s, simulation ends at Sat Dec 10 09:49:17 2022
# ----------------------------------Generator Type 3--------------------------------
# Greedy
# --------New experiments with  k=256----------------------
# Start to simulate... at Sat Dec 10 09:49:18 2022
# PCS:0.173, PGS:0.173
# Total time used: 6.584740161895752s, simulation ends at Sat Dec 10 09:49:24 2022
# This problem has 512 alternatives
# ----------------------------------Generator Type 0--------------------------------
# Greedy
# --------New experiments with  k=512----------------------
# Start to simulate... at Sat Dec 10 09:49:25 2022
# PCS:0.125, PGS:0.125
# Total time used: 13.238714218139648s, simulation ends at Sat Dec 10 09:49:37 2022
# ----------------------------------Generator Type 1--------------------------------
# Greedy
# --------New experiments with  k=512----------------------
# Start to simulate... at Sat Dec 10 09:49:38 2022
# PCS:0.185, PGS:0.185
# Total time used: 13.080976247787476s, simulation ends at Sat Dec 10 09:49:50 2022
# ----------------------------------Generator Type 2--------------------------------
# Greedy
# --------New experiments with  k=512----------------------
# Start to simulate... at Sat Dec 10 09:49:51 2022
# PCS:0.184, PGS:0.184
# Total time used: 13.09589409828186s, simulation ends at Sat Dec 10 09:50:03 2022
# ----------------------------------Generator Type 3--------------------------------
# Greedy
# --------New experiments with  k=512----------------------
# Start to simulate... at Sat Dec 10 09:50:04 2022
# PCS:0.152, PGS:0.152
# Total time used: 13.063256740570068s, simulation ends at Sat Dec 10 09:50:16 2022
# This problem has 1024 alternatives
# ----------------------------------Generator Type 0--------------------------------
# Greedy
# --------New experiments with  k=1024----------------------
# Start to simulate... at Sat Dec 10 09:50:18 2022
# PCS:0.097, PGS:0.097
# Total time used: 26.870710134506226s, simulation ends at Sat Dec 10 09:50:43 2022
# ----------------------------------Generator Type 1--------------------------------
# Greedy
# --------New experiments with  k=1024----------------------
# Start to simulate... at Sat Dec 10 09:50:44 2022
# PCS:0.187, PGS:0.187
# Total time used: 26.18541383743286s, simulation ends at Sat Dec 10 09:51:09 2022
# ----------------------------------Generator Type 2--------------------------------
# Greedy
# --------New experiments with  k=1024----------------------
# Start to simulate... at Sat Dec 10 09:51:10 2022
# PCS:0.176, PGS:0.176
# Total time used: 26.50960659980774s, simulation ends at Sat Dec 10 09:51:36 2022
# ----------------------------------Generator Type 3--------------------------------
# Greedy
# --------New experiments with  k=1024----------------------
# Start to simulate... at Sat Dec 10 09:51:37 2022
# PCS:0.122, PGS:0.122
# Total time used: 26.291187047958374s, simulation ends at Sat Dec 10 09:52:02 2022
# This problem has 2048 alternatives
# ----------------------------------Generator Type 0--------------------------------
# Greedy
# --------New experiments with  k=2048----------------------
# Start to simulate... at Sat Dec 10 09:52:04 2022
# PCS:0.11, PGS:0.11
# Total time used: 55.96861934661865s, simulation ends at Sat Dec 10 09:52:58 2022
# ----------------------------------Generator Type 1--------------------------------
# Greedy
# --------New experiments with  k=2048----------------------
# Start to simulate... at Sat Dec 10 09:53:00 2022
# PCS:0.162, PGS:0.162
# Total time used: 55.34633255004883s, simulation ends at Sat Dec 10 09:53:54 2022
# ----------------------------------Generator Type 2--------------------------------
# Greedy
# --------New experiments with  k=2048----------------------
# Start to simulate... at Sat Dec 10 09:53:55 2022
# PCS:0.161, PGS:0.161
# Total time used: 55.42721247673035s, simulation ends at Sat Dec 10 09:54:49 2022
# ----------------------------------Generator Type 3--------------------------------
# Greedy
# --------New experiments with  k=2048----------------------
# Start to simulate... at Sat Dec 10 09:54:50 2022
# PCS:0.122, PGS:0.122
# Total time used: 55.41005849838257s, simulation ends at Sat Dec 10 09:55:45 2022
# This problem has 4096 alternatives
# ----------------------------------Generator Type 0--------------------------------
# Greedy
# --------New experiments with  k=4096----------------------
# Start to simulate... at Sat Dec 10 09:55:46 2022
# PCS:0.126, PGS:0.126
# Total time used: 124.19761443138123s, simulation ends at Sat Dec 10 09:57:49 2022
# ----------------------------------Generator Type 1--------------------------------
# Greedy
# --------New experiments with  k=4096----------------------
# Start to simulate... at Sat Dec 10 09:57:50 2022
# PCS:0.147, PGS:0.147
# Total time used: 124.04924869537354s, simulation ends at Sat Dec 10 09:59:53 2022
# ----------------------------------Generator Type 2--------------------------------
# Greedy
# --------New experiments with  k=4096----------------------
# Start to simulate... at Sat Dec 10 09:59:54 2022
# PCS:0.138, PGS:0.138
# Total time used: 123.9750907421112s, simulation ends at Sat Dec 10 10:01:57 2022
# ----------------------------------Generator Type 3--------------------------------
# Greedy
# --------New experiments with  k=4096----------------------
# Start to simulate... at Sat Dec 10 10:01:58 2022
# PCS:0.104, PGS:0.104
# Total time used: 123.857106924057s, simulation ends at Sat Dec 10 10:04:01 2022
# This problem has 8192 alternatives
# ----------------------------------Generator Type 0--------------------------------
# Greedy
# --------New experiments with  k=8192----------------------
# Start to simulate... at Sat Dec 10 10:04:04 2022
# PCS:0.115, PGS:0.115
# Total time used: 296.4245297908783s, simulation ends at Sat Dec 10 10:08:58 2022
# ----------------------------------Generator Type 1--------------------------------
# Greedy
# --------New experiments with  k=8192----------------------
# Start to simulate... at Sat Dec 10 10:09:00 2022
# PCS:0.154, PGS:0.154
# Total time used: 297.38108801841736s, simulation ends at Sat Dec 10 10:13:56 2022
# ----------------------------------Generator Type 2--------------------------------
# Greedy
# --------New experiments with  k=8192----------------------
# Start to simulate... at Sat Dec 10 10:13:57 2022
# PCS:0.148, PGS:0.148
# Total time used: 299.1128375530243s, simulation ends at Sat Dec 10 10:18:55 2022
# ----------------------------------Generator Type 3--------------------------------
# Greedy
# --------New experiments with  k=8192----------------------
# Start to simulate... at Sat Dec 10 10:18:56 2022
# PCS:0.114, PGS:0.114
# Total time used: 299.99431014060974s, simulation ends at Sat Dec 10 10:23:55 2022
# This problem has 16384 alternatives
# ----------------------------------Generator Type 0--------------------------------
# Greedy
# --------New experiments with  k=16384----------------------
# Start to simulate... at Sat Dec 10 10:23:58 2022
# PCS:0.126, PGS:0.126
# Total time used: 801.0596985816956s, simulation ends at Sat Dec 10 10:37:18 2022
# ----------------------------------Generator Type 1--------------------------------
# Greedy
# --------New experiments with  k=16384----------------------
# Start to simulate... at Sat Dec 10 10:37:19 2022
# PCS:0.134, PGS:0.134
# Total time used: 799.8597288131714s, simulation ends at Sat Dec 10 10:50:38 2022
# ----------------------------------Generator Type 2--------------------------------
# Greedy
# --------New experiments with  k=16384----------------------
# Start to simulate... at Sat Dec 10 10:50:39 2022
# PCS:0.138, PGS:0.138
# Total time used: 797.2405469417572s, simulation ends at Sat Dec 10 11:03:55 2022
# ----------------------------------Generator Type 3--------------------------------
# Greedy
# --------New experiments with  k=16384----------------------
# Start to simulate... at Sat Dec 10 11:03:56 2022
# PCS:0.094, PGS:0.094
# Total time used: 807.7501380443573s, simulation ends at Sat Dec 10 11:17:23 2022
# This problem has 32768 alternatives
# ----------------------------------Generator Type 0--------------------------------
# Greedy
# --------New experiments with  k=32768----------------------
# Start to simulate... at Sat Dec 10 11:17:29 2022
# PCS:0.129, PGS:0.129
# Total time used: 2395.866639137268s, simulation ends at Sat Dec 10 11:57:23 2022
# ----------------------------------Generator Type 1--------------------------------
# Greedy
# --------New experiments with  k=32768----------------------
# Start to simulate... at Sat Dec 10 11:57:25 2022
# PCS:0.137, PGS:0.137
# Total time used: 2401.0112159252167s, simulation ends at Sat Dec 10 12:37:24 2022
# ----------------------------------Generator Type 2--------------------------------
# Greedy
# --------New experiments with  k=32768----------------------
# Start to simulate... at Sat Dec 10 12:37:26 2022
# PCS:0.129, PGS:0.129
# Total time used: 2414.957136154175s, simulation ends at Sat Dec 10 13:17:39 2022
# ----------------------------------Generator Type 3--------------------------------
# Greedy
# --------New experiments with  k=32768----------------------
# Start to simulate... at Sat Dec 10 13:17:41 2022
# PCS:0.103, PGS:0.103
# Total time used: 2403.6784365177155s, simulation ends at Sat Dec 10 13:57:43 2022
# This problem has 65536 alternatives
# ----------------------------------Generator Type 0--------------------------------
# Greedy
# --------New experiments with  k=65536----------------------
# Start to simulate... at Sat Dec 10 13:57:53 2022
# PCS:0.119, PGS:0.119
# Total time used: 9631.507528066635s, simulation ends at Sat Dec 10 16:38:22 2022
# ----------------------------------Generator Type 1--------------------------------
# Greedy
# --------New experiments with  k=65536----------------------
# Start to simulate... at Sat Dec 10 16:38:24 2022
# PCS:0.146, PGS:0.146
# Total time used: 8801.9271068573s, simulation ends at Sat Dec 10 19:05:04 2022
# ----------------------------------Generator Type 2--------------------------------
# Greedy
# --------New experiments with  k=65536----------------------
# Start to simulate... at Sat Dec 10 19:05:06 2022
# PCS:0.127, PGS:0.127
# Total time used: 8824.859350919724s, simulation ends at Sat Dec 10 21:32:09 2022
# ----------------------------------Generator Type 3--------------------------------
# Greedy
# --------New experiments with  k=65536----------------------
# Start to simulate... at Sat Dec 10 21:32:11 2022
# PCS:0.107, PGS:0.107
# Total time used: 8706.08302950859s, simulation ends at Sat Dec 10 23:57:15 2022
# [0.368,
#  0.681,
#  0.659,
#  0.574,
#  0.253,
#  0.552,
#  0.565,
#  0.432,
#  0.188,
#  0.46,
#  0.436,
#  0.327,
#  0.128,
#  0.386,
#  0.353,
#  0.29,
#  0.122,
#  0.295,
#  0.29,
#  0.227,
#  0.134,
#  0.256,
#  0.262,
#  0.198,
#  0.132,
#  0.179,
#  0.208,
#  0.173,
#  0.125,
#  0.185,
#  0.184,
#  0.152,
#  0.097,
#  0.187,
#  0.176,
#  0.122,
#  0.11,
#  0.162,
#  0.161,
#  0.122,
#  0.126,
#  0.147,
#  0.138,
#  0.104,
#  0.115,
#  0.154,
#  0.148,
#  0.114,
#  0.126,
#  0.134,
#  0.138,
#  0.094,
#  0.129,
#  0.137,
#  0.129,
#  0.103,
#  0.119,
#  0.146,
#  0.127,
#  0.107]
