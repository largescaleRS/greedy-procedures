# %%
import numpy as np
import ray
import matplotlib.pyplot as plt
import time
from utils import *
from procedures import *

plt.rcParams["font.sans-serif"] = "DejaVu Sans"
plt.rcParams["mathtext.default"]  = "it"
plt.rcParams["mathtext.fontset"]  = "dejavusans"

# %%
# Number of parallel threads to be used
# Shut down any existing Ray processes
# Initialize Ray with the specified number of parallel threads

num_cpus=96
ray.shutdown()
ray.init(num_cpus=num_cpus, ignore_reinit_error=True)
# Out:
# 2023-01-18 00:33:23,518	INFO worker.py:1529 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# RayContext(dashboard_url='127.0.0.1:8265', python_version='3.8.15', ray_version='2.2.0', ray_commit='b6af0887ee5f2e460202133791ad941a41f15beb', address_info={'node_ip_address': '127.0.0.1', 'raylet_ip_address': '127.0.0.1', 'redis_address': None, 'object_store_address': 'tcp://127.0.0.1:65031', 'raylet_socket_name': 'tcp://127.0.0.1:60261', 'webui_url': '127.0.0.1:8265', 'session_dir': 'C:\\Users\\admin\\AppData\\Local\\Temp\\2\\ray\\session_2023-01-18_00-33-21_598160_72436', 'metrics_export_port': 62374, 'gcs_address': '127.0.0.1:64246', 'address': '127.0.0.1:64246', 'dashboard_agent_listen_port': 52365, 'node_id': 'bef84af43e0e2b2c3db366473cc89e570bc78f40f6fa245c7da83b15'})

# %% [raw]
# The experiments included are all conducted on lab servers with more than 50 CPU cores (supporting more than 100 concurrent computing threads) and 512 GB memory.
#
# Even if your PC or server does not have 48 CPUs to support 96 parallel threads (Ray actors), you CAN also run the codes. But, when running the computing blocks, the warning of too many actors may appear. You can ignore the warnings and wait for the completed results. The total computing time depends on how many CPUs are TRULY used and the performance of your CPUs. It may take HOURS to finish one single experiment if you only have 8 CPUs on your computer. A 512 GB of memory is NOT necessary, but there is a risk of memory overload if it is too small.
#
# You CAN change the num_cpus (16 if there are 8 CPUs) to a smaller number to avoid the warnings or overload of your computer.
#
# This set of experiments takes 17 hours even on a server with more than 50 CPU cores.

# %% [raw]
# TpMaxSimulator is a C lib, which is used as a Python extension module.
# The Python codes are translated from a Java version (at https://github.com/biazhong/FBKT/blob/778fb1ab999de22ab85ee3d3ae1d3c9f3a1d52fc/FBKTSpark/src/main/java/problems/TpMax.java).
#
# To speed up the simulation, we use Cython to compile it into C lib. The setup.py is used for this. See https://cython.readthedocs.io/en/latest/src/quickstart/build.html (Building a Cython module using setup tools) for guidance on how to build the .pyx file into a Python extension module.
#
# The .so files are the produced modules for different Python versions on MAC OS. The .pyd, .lib, and .exp files are the produced modules on Windows. We include the files for Python 3.8 and 3.9. If your Python version is not covered, please compile the .pyx file.

# %%
from TpMaxSimulator import TpMaxSimulator

# %% [raw]
# WARNING: Due to MAC OS's security check on external software, the first time you use TpMaxSimulator you need to allow external software permission in Settings - Privacy and Security.

# %% [raw]
# Table 2 and Table 3 involves the results of six procedures (FBKT, FBKT-Seeding, EFG, EFGPlus, Modified SH, SH) on
# 4 problem types with parameters (20, 20), (30, 30), (45, 30), and (45, 45) respectively.
#
# The experiments under (20, 20) and (30, 30) are done in Table_2and3_Part1.ipynb.
#
# The experiments under (45, 30) and (45, 45) are done in Table_2and3_Part2.ipynb.
#
# The experiments under the SH procedure are done in this Table_2and3_SH.ipynb.
#
# The results of these notebooks are recorded in Table 2 and Table 3.
#
# NOTICE: We round the PCS and PGS results to two decimal places.

# %% [raw]
# Furthermore, four schemes of total sampling budget are used, i.e., 30k, 50k, 100k, and 200k.
# Table 2 includes the PCS under 50k, 100k, 200k.
# Table 3 includes the PGS under 30k, 50k, 100k.
#
# Please notice the order of the experiments.
#
# For each problem_type, two layers of for-loop are used. The first layer is used to iterate the budget scheme, while the second is used to iterate the procedures.

# %%
recipes0 = [30, 50, 100, 200]
recipes1 = [(2, 28), (4, 46), (9, 91),(18, 182)]
recipes2 = [(27, 3), (45, 5), (90, 10),(180, 20)]
recipes3 = [(6, 21, 3), (10, 35, 5), (20, 70, 10),(40, 140, 20)]
recipes4 = [30, 50, 100, 200]

n_recipe = len(recipes0)
n_replications = 500
G = 11
_njobs, _nstages, _burnin = 1050, 3, 1000

# %%
FBKT_results = []
FBKTS_results = []
EFG_results = []
EFGPlus_results = []
MoSH_results = []

# %%
# problem_types = [(20, 20)]
# seed = 20230118 + 20 + 20 # date + experiment setting
# np.random.seed(seed)
# rng = np.random.default_rng(seed)


# for problem_type in problem_types:
#     slns, means = loadTPMax(problem_type[0], problem_type[1])
#     print("problem size:{}".format(len(slns)))
#     generators = [TpMaxGenerator(_njobs, _nstages, _burnin, slns, means, TpMaxSimulator) for i in range(n_replications)]
#     for i in range(n_recipe):
        
#         n = recipes0[i]
#         print("FBKT")
#         PCS, PGS = parallel_experiments(rng,  generators, policy=FBKT, remote_policy=remote_FBKT, 
#                                         args={"nsd":0, "n":n, "seeding":False})
#         FBKT_results.append([PCS,PGS])
        
#         recipe = recipes1[i]
#         nsd = recipe[0]
#         n0 = recipe[1]
        
#         print("FBKTSeeding")
#         PCS, PGS = parallel_experiments(rng,  generators, policy=FBKT, remote_policy=remote_FBKT, 
#                                         args={"nsd":nsd, "n": n0, "seeding":True})
#         FBKTS_results.append([PCS,PGS])
        
#         recipe = recipes2[i]
#         n0 = recipe[0]
#         ng = recipe[1]
        
#         print("EFG")
#         PCS, PGS = parallel_experiments(rng,  generators, policy=EFG, remote_policy=remote_EFG, 
#                                         args={"n0":n0, "ng":ng})
#         EFG_results.append([PCS,PGS])
    
        
#         recipe = recipes3[i]
#         nsd = recipe[0]
#         n0 = recipe[1]
#         ng = recipe[2]
        
#         print("EFGPlus")
#         PCS, PGS = parallel_experiments(rng,  generators, policy=EFGPlus, remote_policy=remote_EFGPlus,  
#                                         args={"nsd":nsd, "n0":n0, "ng":ng, "G":G})

#         EFGPlus_results.append([PCS,PGS])
        
#         n = recipes4[i]
#         if n >= 81:
#             print("Modified Sequential Halving")
#             PCS, PGS = parallel_experiments(rng,  generators, policy=ModifiedSH, remote_policy=remote_ModifiedSH,  args={"n":n})
#             MoSH_results.append([PCS,PGS])

# %%
# problem_types = [(30, 30)]
# seed = 20230118+30+30
# np.random.seed(seed)
# rng = np.random.default_rng(seed)


# for problem_type in problem_types:
#     slns, means = loadTPMax(problem_type[0], problem_type[1])
#     print("problem size:{}".format(len(slns)))
#     generators = [TpMaxGenerator(_njobs, _nstages, _burnin, slns, means, TpMaxSimulator) for i in range(n_replications)]
#     for i in range(n_recipe):
        
#         n = recipes0[i]
#         print("FBKT")
#         PCS, PGS = parallel_experiments(rng,  generators, policy=FBKT, remote_policy=remote_FBKT, 
#                                         args={"nsd":0, "n":n, "seeding":False})
#         FBKT_results.append([PCS,PGS])
        
#         recipe = recipes1[i]
#         nsd = recipe[0]
#         n0 = recipe[1]
        
#         print("FBKTSeeding")
#         PCS, PGS = parallel_experiments(rng,  generators, policy=FBKT, remote_policy=remote_FBKT, 
#                                         args={"nsd":nsd, "n": n0, "seeding":True})
#         FBKTS_results.append([PCS,PGS])
        
#         recipe = recipes2[i]
#         n0 = recipe[0]
#         ng = recipe[1]
        
#         print("EFG")
#         PCS, PGS = parallel_experiments(rng,  generators, policy=EFG, remote_policy=remote_EFG, 
#                                         args={"n0":n0, "ng":ng})
#         EFG_results.append([PCS,PGS])
    
        
#         recipe = recipes3[i]
#         nsd = recipe[0]
#         n0 = recipe[1]
#         ng = recipe[2]
        
#         print("EFGPlus")
#         PCS, PGS = parallel_experiments(rng,  generators, policy=EFGPlus, remote_policy=remote_EFGPlus,  
#                                         args={"nsd":nsd, "n0":n0, "ng":ng, "G":G})

#         EFGPlus_results.append([PCS,PGS])
        
#         n = recipes4[i]
#         if n >= 81:
#             print("Modified Sequential Halving")
#             PCS, PGS = parallel_experiments(rng,  generators, policy=ModifiedSH, remote_policy=remote_ModifiedSH,  args={"n":n})
#             MoSH_results.append([PCS,PGS])

# %%
problem_types = [(45, 30)]
seed = 20230118+45+30
np.random.seed(seed)
rng = np.random.default_rng(seed)


for problem_type in problem_types:
    slns, means = loadTPMax(problem_type[0], problem_type[1])
    print("problem size:{}".format(len(slns)))
    generators = [TpMaxGenerator(_njobs, _nstages, _burnin, slns, means, TpMaxSimulator) for i in range(n_replications)]
    for i in range(n_recipe):
        
        n = recipes0[i]
        print("FBKT")
        PCS, PGS = parallel_experiments(rng,  generators, policy=FBKT, remote_policy=remote_FBKT, 
                                        args={"nsd":0, "n":n, "seeding":False})
        FBKT_results.append([PCS,PGS])
        
        recipe = recipes1[i]
        nsd = recipe[0]
        n0 = recipe[1]
        
        print("FBKTSeeding")
        PCS, PGS = parallel_experiments(rng,  generators, policy=FBKT, remote_policy=remote_FBKT, 
                                        args={"nsd":nsd, "n": n0, "seeding":True})
        FBKTS_results.append([PCS,PGS])
        
        recipe = recipes2[i]
        n0 = recipe[0]
        ng = recipe[1]
        
        print("EFG")
        PCS, PGS = parallel_experiments(rng,  generators, policy=EFG, remote_policy=remote_EFG, 
                                        args={"n0":n0, "ng":ng})
        EFG_results.append([PCS,PGS])
    
        
        recipe = recipes3[i]
        nsd = recipe[0]
        n0 = recipe[1]
        ng = recipe[2]
        
        print("EFGPlus")
        PCS, PGS = parallel_experiments(rng,  generators, policy=EFGPlus, remote_policy=remote_EFGPlus,  
                                        args={"nsd":nsd, "n0":n0, "ng":ng, "G":G})

        EFGPlus_results.append([PCS,PGS])
        
        n = recipes4[i]
        if n >= 81:
            print("Modified Sequential Halving")
            PCS, PGS = parallel_experiments(rng,  generators, policy=ModifiedSH, remote_policy=remote_ModifiedSH,  args={"n":n})
            MoSH_results.append([PCS,PGS])
# Out:
# problem size:27434
# FBKT
# --------New experiments with  k=27434----------------------
# Start to simulate... at Wed Jan 18 00:33:34 2023
# PCS:0.218, PGS:0.692
# Total time used: 418.71055150032043s, simulation ends at Wed Jan 18 00:40:32 2023
# FBKTSeeding
# --------New experiments with  k=27434----------------------
# Start to simulate... at Wed Jan 18 00:40:33 2023
# PCS:0.284, PGS:0.782
# Total time used: 429.9957115650177s, simulation ends at Wed Jan 18 00:47:42 2023
# EFG
# --------New experiments with  k=27434----------------------
# Start to simulate... at Wed Jan 18 00:47:43 2023
# PCS:0.202, PGS:0.544
# Total time used: 445.2137973308563s, simulation ends at Wed Jan 18 00:55:07 2023
# EFGPlus
# --------New experiments with  k=27434----------------------
# Start to simulate... at Wed Jan 18 00:55:08 2023
# PCS:0.33, PGS:0.786
# Total time used: 451.12061977386475s, simulation ends at Wed Jan 18 01:02:38 2023
# FBKT
# --------New experiments with  k=27434----------------------
# Start to simulate... at Wed Jan 18 01:02:39 2023
# PCS:0.296, PGS:0.734
# Total time used: 702.7198543548584s, simulation ends at Wed Jan 18 01:14:21 2023
# FBKTSeeding
# --------New experiments with  k=27434----------------------
# Start to simulate... at Wed Jan 18 01:14:22 2023
# PCS:0.34, PGS:0.826
# Total time used: 710.091796875s, simulation ends at Wed Jan 18 01:26:11 2023
# EFG
# --------New experiments with  k=27434----------------------
# Start to simulate... at Wed Jan 18 01:26:12 2023
# PCS:0.218, PGS:0.602
# Total time used: 767.9379813671112s, simulation ends at Wed Jan 18 01:38:59 2023
# EFGPlus
# --------New experiments with  k=27434----------------------
# Start to simulate... at Wed Jan 18 01:39:00 2023
# PCS:0.372, PGS:0.898
# Total time used: 771.425041437149s, simulation ends at Wed Jan 18 01:51:51 2023
# FBKT
# --------New experiments with  k=27434----------------------
# Start to simulate... at Wed Jan 18 01:51:51 2023
# PCS:0.344, PGS:0.818
# Total time used: 1480.2963783740997s, simulation ends at Wed Jan 18 02:16:31 2023
# FBKTSeeding
# --------New experiments with  k=27434----------------------
# Start to simulate... at Wed Jan 18 02:16:31 2023
# PCS:0.37, PGS:0.876
# Total time used: 1478.0029184818268s, simulation ends at Wed Jan 18 02:41:09 2023
# EFG
# --------New experiments with  k=27434----------------------
# Start to simulate... at Wed Jan 18 02:41:09 2023
# PCS:0.236, PGS:0.646
# Total time used: 1529.0070168972015s, simulation ends at Wed Jan 18 03:06:38 2023
# EFGPlus
# --------New experiments with  k=27434----------------------
# Start to simulate... at Wed Jan 18 03:06:38 2023
# PCS:0.448, PGS:0.944
# Total time used: 1538.5426850318909s, simulation ends at Wed Jan 18 03:32:16 2023
# Modified Sequential Halving
# --------New experiments with  k=27434----------------------
# Start to simulate... at Wed Jan 18 03:32:17 2023
# PCS:0.57, PGS:0.986
# Total time used: 830.6737759113312s, simulation ends at Wed Jan 18 03:46:07 2023
# FBKT
# --------New experiments with  k=27434----------------------
# Start to simulate... at Wed Jan 18 03:46:08 2023
# PCS:0.394, PGS:0.888
# Total time used: 2956.040731906891s, simulation ends at Wed Jan 18 04:35:23 2023
# FBKTSeeding
# --------New experiments with  k=27434----------------------
# Start to simulate... at Wed Jan 18 04:35:24 2023
# PCS:0.452, PGS:0.94
# Total time used: 2946.080041885376s, simulation ends at Wed Jan 18 05:24:29 2023
# EFG
# --------New experiments with  k=27434----------------------
# Start to simulate... at Wed Jan 18 05:24:30 2023
# PCS:0.286, PGS:0.724
# Total time used: 3057.7364711761475s, simulation ends at Wed Jan 18 06:15:27 2023
# EFGPlus
# --------New experiments with  k=27434----------------------
# Start to simulate... at Wed Jan 18 06:15:27 2023
# PCS:0.53, PGS:0.982
# Total time used: 3066.4483680725098s, simulation ends at Wed Jan 18 07:06:33 2023
# Modified Sequential Halving
# --------New experiments with  k=27434----------------------
# Start to simulate... at Wed Jan 18 07:06:34 2023
# PCS:0.57, PGS:1.0
# Total time used: 1659.753084897995s, simulation ends at Wed Jan 18 07:34:13 2023

# %%
problem_types = [(45,45)]
seed = 20230118+45+45
np.random.seed(seed)
rng = np.random.default_rng(seed)


for problem_type in problem_types:
    slns, means = loadTPMax(problem_type[0], problem_type[1])
    print("problem size:{}".format(len(slns)))
    generators = [TpMaxGenerator(_njobs, _nstages, _burnin, slns, means, TpMaxSimulator) for i in range(n_replications)]
    for i in range(n_recipe):
        
        n = recipes0[i]
        print("FBKT")
        PCS, PGS = parallel_experiments(rng,  generators, policy=FBKT, remote_policy=remote_FBKT, 
                                        args={"nsd":0, "n":n, "seeding":False})
        FBKT_results.append([PCS,PGS])
        
        recipe = recipes1[i]
        nsd = recipe[0]
        n0 = recipe[1]
        
        print("FBKTSeeding")
        PCS, PGS = parallel_experiments(rng,  generators, policy=FBKT, remote_policy=remote_FBKT, 
                                        args={"nsd":nsd, "n": n0, "seeding":True})
        FBKTS_results.append([PCS,PGS])
        
        recipe = recipes2[i]
        n0 = recipe[0]
        ng = recipe[1]
        
        print("EFG")
        PCS, PGS = parallel_experiments(rng,  generators, policy=EFG, remote_policy=remote_EFG, 
                                        args={"n0":n0, "ng":ng})
        EFG_results.append([PCS,PGS])
    
        
        recipe = recipes3[i]
        nsd = recipe[0]
        n0 = recipe[1]
        ng = recipe[2]
        
        print("EFGPlus")
        PCS, PGS = parallel_experiments(rng,  generators, policy=EFGPlus, remote_policy=remote_EFGPlus,  
                                        args={"nsd":nsd, "n0":n0, "ng":ng, "G":G})

        EFGPlus_results.append([PCS,PGS])
        
        n = recipes4[i]
        if n >= 81:
            print("Modified Sequential Halving")
            PCS, PGS = parallel_experiments(rng,  generators, policy=ModifiedSH, remote_policy=remote_ModifiedSH,  args={"n":n})
            MoSH_results.append([PCS,PGS])
# Out:
# problem size:41624
# FBKT
# --------New experiments with  k=41624----------------------
# Start to simulate... at Wed Jan 18 07:34:15 2023
# PCS:0.332, PGS:0.636
# Total time used: 655.7323248386383s, simulation ends at Wed Jan 18 07:45:10 2023
# FBKTSeeding
# --------New experiments with  k=41624----------------------
# Start to simulate... at Wed Jan 18 07:45:11 2023
# PCS:0.334, PGS:0.702
# Total time used: 673.4152181148529s, simulation ends at Wed Jan 18 07:56:23 2023
# EFG
# --------New experiments with  k=41624----------------------
# Start to simulate... at Wed Jan 18 07:56:24 2023
# PCS:0.27, PGS:0.482
# Total time used: 701.2039394378662s, simulation ends at Wed Jan 18 08:08:05 2023
# EFGPlus
# --------New experiments with  k=41624----------------------
# Start to simulate... at Wed Jan 18 08:08:05 2023
# PCS:0.434, PGS:0.778
# Total time used: 709.9775686264038s, simulation ends at Wed Jan 18 08:19:55 2023
# FBKT
# --------New experiments with  k=41624----------------------
# Start to simulate... at Wed Jan 18 08:19:55 2023
# PCS:0.366, PGS:0.652
# Total time used: 1099.5051610469818s, simulation ends at Wed Jan 18 08:38:14 2023
# FBKTSeeding
# --------New experiments with  k=41624----------------------
# Start to simulate... at Wed Jan 18 08:38:15 2023
# PCS:0.4, PGS:0.706
# Total time used: 1116.5013053417206s, simulation ends at Wed Jan 18 08:56:51 2023
# EFG
# --------New experiments with  k=41624----------------------
# Start to simulate... at Wed Jan 18 08:56:51 2023
# PCS:0.258, PGS:0.514
# Total time used: 1162.8394796848297s, simulation ends at Wed Jan 18 09:16:13 2023
# EFGPlus
# --------New experiments with  k=41624----------------------
# Start to simulate... at Wed Jan 18 09:16:14 2023
# PCS:0.504, PGS:0.88
# Total time used: 1173.6604013442993s, simulation ends at Wed Jan 18 09:35:47 2023
# FBKT
# --------New experiments with  k=41624----------------------
# Start to simulate... at Wed Jan 18 09:35:48 2023
# PCS:0.398, PGS:0.71
# Total time used: 2234.5516023635864s, simulation ends at Wed Jan 18 10:13:02 2023
# FBKTSeeding
# --------New experiments with  k=41624----------------------
# Start to simulate... at Wed Jan 18 10:13:02 2023
# PCS:0.47, PGS:0.8
# Total time used: 2207.4428901672363s, simulation ends at Wed Jan 18 10:49:49 2023
# EFG
# --------New experiments with  k=41624----------------------
# Start to simulate... at Wed Jan 18 10:49:50 2023
# PCS:0.296, PGS:0.58
# Total time used: 2276.6178736686707s, simulation ends at Wed Jan 18 11:27:46 2023
# EFGPlus
# --------New experiments with  k=41624----------------------
# Start to simulate... at Wed Jan 18 11:27:46 2023
# PCS:0.632, PGS:0.916
# Total time used: 2289.524058818817s, simulation ends at Wed Jan 18 12:05:55 2023
# Modified Sequential Halving
# --------New experiments with  k=41624----------------------
# Start to simulate... at Wed Jan 18 12:05:56 2023
# PCS:0.65, PGS:0.97
# Total time used: 1361.114242553711s, simulation ends at Wed Jan 18 12:28:36 2023
# FBKT
# --------New experiments with  k=41624----------------------
# Start to simulate... at Wed Jan 18 12:28:37 2023
# PCS:0.5, PGS:0.82
# Total time used: 4464.342111110687s, simulation ends at Wed Jan 18 13:43:01 2023
# FBKTSeeding
# --------New experiments with  k=41624----------------------
# Start to simulate... at Wed Jan 18 13:43:01 2023
# PCS:0.5, PGS:0.864
# Total time used: 4455.187028169632s, simulation ends at Wed Jan 18 14:57:16 2023
# EFG
# --------New experiments with  k=41624----------------------
# Start to simulate... at Wed Jan 18 14:57:17 2023
# PCS:0.352, PGS:0.658
# Total time used: 4648.8812437057495s, simulation ends at Wed Jan 18 16:14:45 2023
# EFGPlus
# --------New experiments with  k=41624----------------------
# Start to simulate... at Wed Jan 18 16:14:45 2023
# PCS:0.682, PGS:0.948
# Total time used: 4611.480681657791s, simulation ends at Wed Jan 18 17:31:36 2023
# Modified Sequential Halving
# --------New experiments with  k=41624----------------------
# Start to simulate... at Wed Jan 18 17:31:37 2023
# PCS:0.738, PGS:0.986
# Total time used: 2731.096339941025s, simulation ends at Wed Jan 18 18:17:07 2023
