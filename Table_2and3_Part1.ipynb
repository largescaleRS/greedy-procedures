# %%
import numpy as np
import ray
import matplotlib.pyplot as plt
import time
from utils import *
from procedures import *

plt.rcParams["font.sans-serif"] = "DejaVu Sans"
plt.rcParams["mathtext.default"]  = "it"
plt.rcParams["mathtext.fontset"]  = "dejavusans"

# %%
# Number of parallel threads to be used
# Shut down any existing Ray processes
# Initialize Ray with the specified number of parallel threads

num_cpus=96
ray.shutdown()
ray.init(num_cpus=num_cpus, ignore_reinit_error=True)
# Out:
# 2023-01-18 00:30:02,756	INFO worker.py:1529 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# RayContext(dashboard_url='127.0.0.1:8265', python_version='3.8.8', ray_version='2.2.0', ray_commit='b6af0887ee5f2e460202133791ad941a41f15beb', address_info={'node_ip_address': '127.0.0.1', 'raylet_ip_address': '127.0.0.1', 'redis_address': None, 'object_store_address': 'tcp://127.0.0.1:62558', 'raylet_socket_name': 'tcp://127.0.0.1:63182', 'webui_url': '127.0.0.1:8265', 'session_dir': 'C:\\Users\\lenovo\\AppData\\Local\\Temp\\ray\\session_2023-01-18_00-29-59_097673_25968', 'metrics_export_port': 60436, 'gcs_address': '127.0.0.1:59576', 'address': '127.0.0.1:59576', 'dashboard_agent_listen_port': 52365, 'node_id': '9116050704ad354666eb26296d03813f5c852bc898a47506a0118ff3'})

# %% [raw]
# The experiments included are all conducted on lab servers with more than 50 CPU cores (supporting more than 100 concurrent computing threads) and 512 GB memory.
#
# Even if your PC or server does not have 48 CPUs to support 96 parallel threads (Ray actors), you CAN also run the codes. But, when running the computing blocks, the warning of too many actors may appear. You can ignore the warnings and wait for the completed results. The total computing time depends on how many CPUs are TRULY used and the performance of your CPUs. It may take HOURS to finish one single experiment if you only have 8 CPUs on your computer. A 512 GB of memory is NOT necessary, but there is a risk of memory overload if it is too small.
#
# You CAN change the num_cpus (16 if there are 8 CPUs) to a smaller number to avoid the warnings or overload of your computer.
#
# This set of experiments takes 7 hours even on a server with more than 50 CPU cores.

# %% [raw]
# TpMaxSimulator is a C lib, which is used as a Python extension module.
# The Python codes are translated from a Java version (at https://github.com/biazhong/FBKT/blob/778fb1ab999de22ab85ee3d3ae1d3c9f3a1d52fc/FBKTSpark/src/main/java/problems/TpMax.java).
#
# To speed up the simulation, we use Cython to compile it into C lib. The setup.py is used for this. See https://cython.readthedocs.io/en/latest/src/quickstart/build.html (Building a Cython module using setup tools) for guidance on how to build the .pyx file into a Python extension module.
#
# The .so files are the produced modules for different Python versions on MAC OS. The .pyd, .lib, and .exp files are the produced modules on Windows. We include the files for Python 3.8 and 3.9. If your Python version is not covered, please compile the .pyx file.

# %%
from TpMaxSimulator import TpMaxSimulator

# %% [raw]
# WARNING: Due to MAC OS's security check on external software, the first time you use TpMaxSimulator you need to allow external software permission in Settings - Privacy and Security.

# %% [raw]
# Table 2 and Table 3 involves the results of six procedures (FBKT, FBKT-Seeding, EFG, EFGPlus, Modified SH, SH) on
# 4 problem types with parameters (20, 20), (30, 30), (45, 30), and (45, 45) respectively.
#
# The experiments under (20, 20) and (30, 30) are done in Table_2and3_Part1.ipynb.
#
# The experiments under (45, 30) and (45, 45) are done in Table_2and3_Part2.ipynb.
#
# The experiments under the SH procedure are done in this Table_2and3_SH.ipynb.
#
# The results of these notebooks are recorded in Table 2 and Table 3.

# %% [raw]
# To correspond the results to Table 2 and Table 3, notice the format of the output like the following:
#
#
# FBKT
# --------New experiments with  k=3249----------------------
# Start to simulate... at Wed Jan 18 00:30:18 2023
# PCS:0.314, PGS:0.778
# Total time used: 97.49446177482605s, simulation ends at Wed Jan 18 00:31:55 2023
#
# FBKT is the procedure, the PCS (PGS) is 0.314 (0.778) for the problem with k=3249.
#
# the problem type parameters decide the value of k:
# (20, 20): k = 3249
# (30, 30): k = 11774
# (45, 30): k = 27434
# (45, 45): k = 41624
#
# NOTICE: We round the PCS and PGS results to two decimal places.

# %% [raw]
# Furthermore, four schemes of total sampling budget are used, i.e., 30k, 50k, 100k, and 200k.
# Table 2 includes the PCS under 50k, 100k, 200k.
# Table 3 includes the PGS under 30k, 50k, 100k.
#
# Please notice the order of the experiments.
#
# For each problem_type, two layers of for-loop are used. The first layer is used to iterate the budget scheme, while the second is used to iterate the procedures.

# %%
recipes0 = [30, 50, 100, 200]
recipes1 = [(2, 28), (4, 46), (9, 91),(18, 182)]
recipes2 = [(27, 3), (45, 5), (90, 10),(180, 20)]
recipes3 = [(6, 21, 3), (10, 35, 5), (20, 70, 10),(40, 140, 20)]
recipes4 = [30, 50, 100, 200]

n_recipe = len(recipes0)
n_replications = 500
G = 11
_njobs, _nstages, _burnin = 1050, 3, 1000

# %%
FBKT_results = []
FBKTS_results = []
EFG_results = []
EFGPlus_results = []
MoSH_results = []

# %%
problem_types = [(20, 20)]
seed = 20230118 + 20 + 20 # date + experiment setting
np.random.seed(seed)
rng = np.random.default_rng(seed)


for problem_type in problem_types:
    slns, means = loadTPMax(problem_type[0], problem_type[1])
    print("problem size:{}".format(len(slns)))
    generators = [TpMaxGenerator(_njobs, _nstages, _burnin, slns, means, TpMaxSimulator) for i in range(n_replications)]
    for i in range(n_recipe):
        
        n = recipes0[i]
        print("FBKT")
        PCS, PGS = parallel_experiments(rng,  generators, policy=FBKT, remote_policy=remote_FBKT, 
                                        args={"nsd":0, "n":n, "seeding":False})
        FBKT_results.append([PCS,PGS])
        
        recipe = recipes1[i]
        nsd = recipe[0]
        n0 = recipe[1]
        
        print("FBKTSeeding")
        PCS, PGS = parallel_experiments(rng,  generators, policy=FBKT, remote_policy=remote_FBKT, 
                                        args={"nsd":nsd, "n": n0, "seeding":True})
        FBKTS_results.append([PCS,PGS])
        
        recipe = recipes2[i]
        n0 = recipe[0]
        ng = recipe[1]
        
        print("EFG")
        PCS, PGS = parallel_experiments(rng,  generators, policy=EFG, remote_policy=remote_EFG, 
                                        args={"n0":n0, "ng":ng})
        EFG_results.append([PCS,PGS])
    
        
        recipe = recipes3[i]
        nsd = recipe[0]
        n0 = recipe[1]
        ng = recipe[2]
        
        print("EFGPlus")
        PCS, PGS = parallel_experiments(rng,  generators, policy=EFGPlus, remote_policy=remote_EFGPlus,  
                                        args={"nsd":nsd, "n0":n0, "ng":ng, "G":G})

        EFGPlus_results.append([PCS,PGS])
        
        n = recipes4[i]
        if n >= 81:
            print("Modified Sequential Halving")
            PCS, PGS = parallel_experiments(rng,  generators, policy=ModifiedSH, remote_policy=remote_ModifiedSH,  args={"n":n})
            MoSH_results.append([PCS,PGS])
# Out:
# problem size:3249
# FBKT
# --------New experiments with  k=3249----------------------
# Start to simulate... at Wed Jan 18 00:30:18 2023
# PCS:0.314, PGS:0.778
# Total time used: 97.49446177482605s, simulation ends at Wed Jan 18 00:31:55 2023
# FBKTSeeding
# --------New experiments with  k=3249----------------------
# Start to simulate... at Wed Jan 18 00:31:56 2023
# PCS:0.374, PGS:0.862
# Total time used: 101.52243423461914s, simulation ends at Wed Jan 18 00:33:36 2023
# EFG
# --------New experiments with  k=3249----------------------
# Start to simulate... at Wed Jan 18 00:33:37 2023
# PCS:0.266, PGS:0.772
# Total time used: 106.94088983535767s, simulation ends at Wed Jan 18 00:35:23 2023
# EFGPlus
# --------New experiments with  k=3249----------------------
# Start to simulate... at Wed Jan 18 00:35:24 2023
# PCS:0.414, PGS:0.94
# Total time used: 108.89855790138245s, simulation ends at Wed Jan 18 00:37:12 2023
# FBKT
# --------New experiments with  k=3249----------------------
# Start to simulate... at Wed Jan 18 00:37:13 2023
# PCS:0.314, PGS:0.866
# Total time used: 165.2700390815735s, simulation ends at Wed Jan 18 00:39:58 2023
# FBKTSeeding
# --------New experiments with  k=3249----------------------
# Start to simulate... at Wed Jan 18 00:39:58 2023
# PCS:0.412, PGS:0.868
# Total time used: 168.78103256225586s, simulation ends at Wed Jan 18 00:42:46 2023
# EFG
# --------New experiments with  k=3249----------------------
# Start to simulate... at Wed Jan 18 00:42:47 2023
# PCS:0.372, PGS:0.834
# Total time used: 177.71998953819275s, simulation ends at Wed Jan 18 00:45:44 2023
# EFGPlus
# --------New experiments with  k=3249----------------------
# Start to simulate... at Wed Jan 18 00:45:45 2023
# PCS:0.512, PGS:0.982
# Total time used: 180.09857511520386s, simulation ends at Wed Jan 18 00:48:44 2023
# FBKT
# --------New experiments with  k=3249----------------------
# Start to simulate... at Wed Jan 18 00:48:45 2023
# PCS:0.4, PGS:0.936
# Total time used: 335.2816331386566s, simulation ends at Wed Jan 18 00:54:19 2023
# FBKTSeeding
# --------New experiments with  k=3249----------------------
# Start to simulate... at Wed Jan 18 00:54:20 2023
# PCS:0.464, PGS:0.954
# Total time used: 336.12193417549133s, simulation ends at Wed Jan 18 00:59:56 2023
# EFG
# --------New experiments with  k=3249----------------------
# Start to simulate... at Wed Jan 18 00:59:56 2023
# PCS:0.376, PGS:0.88
# Total time used: 354.15002179145813s, simulation ends at Wed Jan 18 01:05:50 2023
# EFGPlus
# --------New experiments with  k=3249----------------------
# Start to simulate... at Wed Jan 18 01:05:50 2023
# PCS:0.586, PGS:0.998
# Total time used: 358.1465048789978s, simulation ends at Wed Jan 18 01:11:48 2023
# Modified Sequential Halving
# --------New experiments with  k=3249----------------------
# Start to simulate... at Wed Jan 18 01:11:48 2023
# PCS:0.606, PGS:0.996
# Total time used: 160.10482501983643s, simulation ends at Wed Jan 18 01:14:28 2023
# FBKT
# --------New experiments with  k=3249----------------------
# Start to simulate... at Wed Jan 18 01:14:29 2023
# PCS:0.51, PGS:0.97
# Total time used: 667.9874668121338s, simulation ends at Wed Jan 18 01:25:36 2023
# FBKTSeeding
# --------New experiments with  k=3249----------------------
# Start to simulate... at Wed Jan 18 01:25:37 2023
# PCS:0.546, PGS:0.992
# Total time used: 663.7009394168854s, simulation ends at Wed Jan 18 01:36:40 2023
# EFG
# --------New experiments with  k=3249----------------------
# Start to simulate... at Wed Jan 18 01:36:40 2023
# PCS:0.43, PGS:0.95
# Total time used: 696.9358608722687s, simulation ends at Wed Jan 18 01:48:17 2023
# EFGPlus
# --------New experiments with  k=3249----------------------
# Start to simulate... at Wed Jan 18 01:48:17 2023
# PCS:0.664, PGS:1.0
# Total time used: 702.5829713344574s, simulation ends at Wed Jan 18 01:59:59 2023
# Modified Sequential Halving
# --------New experiments with  k=3249----------------------
# Start to simulate... at Wed Jan 18 02:00:00 2023
# PCS:0.63, PGS:1.0
# Total time used: 316.28434205055237s, simulation ends at Wed Jan 18 02:05:15 2023

# %%
problem_types = [(30, 30)]
seed = 20230118+30+30
np.random.seed(seed)
rng = np.random.default_rng(seed)


for problem_type in problem_types:
    slns, means = loadTPMax(problem_type[0], problem_type[1])
    print("problem size:{}".format(len(slns)))
    generators = [TpMaxGenerator(_njobs, _nstages, _burnin, slns, means, TpMaxSimulator) for i in range(n_replications)]
    for i in range(n_recipe):
        
        n = recipes0[i]
        print("FBKT")
        PCS, PGS = parallel_experiments(rng,  generators, policy=FBKT, remote_policy=remote_FBKT, 
                                        args={"nsd":0, "n":n, "seeding":False})
        FBKT_results.append([PCS,PGS])
        
        recipe = recipes1[i]
        nsd = recipe[0]
        n0 = recipe[1]
        
        print("FBKTSeeding")
        PCS, PGS = parallel_experiments(rng,  generators, policy=FBKT, remote_policy=remote_FBKT, 
                                        args={"nsd":nsd, "n": n0, "seeding":True})
        FBKTS_results.append([PCS,PGS])
        
        recipe = recipes2[i]
        n0 = recipe[0]
        ng = recipe[1]
        
        print("EFG")
        PCS, PGS = parallel_experiments(rng,  generators, policy=EFG, remote_policy=remote_EFG, 
                                        args={"n0":n0, "ng":ng})
        EFG_results.append([PCS,PGS])
    
        
        recipe = recipes3[i]
        nsd = recipe[0]
        n0 = recipe[1]
        ng = recipe[2]
        
        print("EFGPlus")
        PCS, PGS = parallel_experiments(rng,  generators, policy=EFGPlus, remote_policy=remote_EFGPlus,  
                                        args={"nsd":nsd, "n0":n0, "ng":ng, "G":G})

        EFGPlus_results.append([PCS,PGS])
        
        n = recipes4[i]
        if n >= 81:
            print("Modified Sequential Halving")
            PCS, PGS = parallel_experiments(rng,  generators, policy=ModifiedSH, remote_policy=remote_ModifiedSH,  args={"n":n})
            MoSH_results.append([PCS,PGS])
# Out:
# problem size:11774
# FBKT
# --------New experiments with  k=11774----------------------
# Start to simulate... at Wed Jan 18 02:05:17 2023
# PCS:0.248, PGS:0.668
# Total time used: 359.16936779022217s, simulation ends at Wed Jan 18 02:11:15 2023
# FBKTSeeding
# --------New experiments with  k=11774----------------------
# Start to simulate... at Wed Jan 18 02:11:16 2023
# PCS:0.258, PGS:0.752
# Total time used: 369.4780294895172s, simulation ends at Wed Jan 18 02:17:25 2023
# EFG
# --------New experiments with  k=11774----------------------
# Start to simulate... at Wed Jan 18 02:17:26 2023
# PCS:0.2, PGS:0.534
# Total time used: 380.888001203537s, simulation ends at Wed Jan 18 02:23:46 2023
# EFGPlus
# --------New experiments with  k=11774----------------------
# Start to simulate... at Wed Jan 18 02:23:47 2023
# PCS:0.332, PGS:0.816
# Total time used: 385.1432385444641s, simulation ends at Wed Jan 18 02:30:11 2023
# FBKT
# --------New experiments with  k=11774----------------------
# Start to simulate... at Wed Jan 18 02:30:12 2023
# PCS:0.238, PGS:0.696
# Total time used: 601.6637275218964s, simulation ends at Wed Jan 18 02:40:12 2023
# FBKTSeeding
# --------New experiments with  k=11774----------------------
# Start to simulate... at Wed Jan 18 02:40:13 2023
# PCS:0.306, PGS:0.782
# Total time used: 612.6569719314575s, simulation ends at Wed Jan 18 02:50:25 2023
# EFG
# --------New experiments with  k=11774----------------------
# Start to simulate... at Wed Jan 18 02:50:26 2023
# PCS:0.236, PGS:0.604
# Total time used: 632.7818386554718s, simulation ends at Wed Jan 18 03:00:58 2023
# EFGPlus
# --------New experiments with  k=11774----------------------
# Start to simulate... at Wed Jan 18 03:00:59 2023
# PCS:0.352, PGS:0.854
# Total time used: 637.2396185398102s, simulation ends at Wed Jan 18 03:11:35 2023
# FBKT
# --------New experiments with  k=11774----------------------
# Start to simulate... at Wed Jan 18 03:11:36 2023
# PCS:0.308, PGS:0.79
# Total time used: 1221.2119371891022s, simulation ends at Wed Jan 18 03:31:56 2023
# FBKTSeeding
# --------New experiments with  k=11774----------------------
# Start to simulate... at Wed Jan 18 03:31:58 2023
# PCS:0.336, PGS:0.868
# Total time used: 1220.6561243534088s, simulation ends at Wed Jan 18 03:52:17 2023
# EFG
# --------New experiments with  k=11774----------------------
# Start to simulate... at Wed Jan 18 03:52:18 2023
# PCS:0.242, PGS:0.67
# Total time used: 1263.8381562232971s, simulation ends at Wed Jan 18 04:13:21 2023
# EFGPlus
# --------New experiments with  k=11774----------------------
# Start to simulate... at Wed Jan 18 04:13:22 2023
# PCS:0.384, PGS:0.944
# Total time used: 1268.9364068508148s, simulation ends at Wed Jan 18 04:34:30 2023
# Modified Sequential Halving
# --------New experiments with  k=11774----------------------
# Start to simulate... at Wed Jan 18 04:34:31 2023
# PCS:0.41, PGS:0.974
# Total time used: 651.2643013000488s, simulation ends at Wed Jan 18 04:45:21 2023
# FBKT
# --------New experiments with  k=11774----------------------
# Start to simulate... at Wed Jan 18 04:45:22 2023
# PCS:0.358, PGS:0.848
# Total time used: 2443.8573241233826s, simulation ends at Wed Jan 18 05:26:05 2023
# FBKTSeeding
# --------New experiments with  k=11774----------------------
# Start to simulate... at Wed Jan 18 05:26:06 2023
# PCS:0.414, PGS:0.912
# Total time used: 2442.648479938507s, simulation ends at Wed Jan 18 06:06:47 2023
# EFG
# --------New experiments with  k=11774----------------------
# Start to simulate... at Wed Jan 18 06:06:48 2023
# PCS:0.302, PGS:0.718
# Total time used: 2520.748910665512s, simulation ends at Wed Jan 18 06:48:48 2023
# EFGPlus
# --------New experiments with  k=11774----------------------
# Start to simulate... at Wed Jan 18 06:48:49 2023
# PCS:0.52, PGS:0.974
# Total time used: 2530.1025829315186s, simulation ends at Wed Jan 18 07:30:58 2023
# Modified Sequential Halving
# --------New experiments with  k=11774----------------------
# Start to simulate... at Wed Jan 18 07:30:59 2023
# PCS:0.52, PGS:0.99
# Total time used: 1303.5799601078033s, simulation ends at Wed Jan 18 07:52:42 2023

# %%
# The following parts for (45, 30) and (45, 45) are done in Table_2and3_Part2.ipynb

# %%
# problem_types = [(45, 30)]
# seed = 20230118+45+30
# np.random.seed(seed)
# rng = np.random.default_rng(seed)


# for problem_type in problem_types:
#     slns, means = loadTPMax(problem_type[0], problem_type[1])
#     print("problem size:{}".format(len(slns)))
#     generators = [TpMaxGenerator(_njobs, _nstages, _burnin, slns, means, TpMaxSimulator) for i in range(n_replications)]
#     for i in range(n_recipe):
        
#         n = recipes0[i]
#         print("FBKT")
#         PCS, PGS = parallel_experiments(rng,  generators, policy=FBKT, remote_policy=remote_FBKT, 
#                                         args={"nsd":0, "n":n, "seeding":False})
#         FBKT_results.append([PCS,PGS])
        
#         recipe = recipes1[i]
#         nsd = recipe[0]
#         n0 = recipe[1]
        
#         print("FBKTSeeding")
#         PCS, PGS = parallel_experiments(rng,  generators, policy=FBKT, remote_policy=remote_FBKT, 
#                                         args={"nsd":nsd, "n": n0, "seeding":True})
#         FBKTS_results.append([PCS,PGS])
        
#         recipe = recipes2[i]
#         n0 = recipe[0]
#         ng = recipe[1]
        
#         print("EFG")
#         PCS, PGS = parallel_experiments(rng,  generators, policy=EFG, remote_policy=remote_EFG, 
#                                         args={"n0":n0, "ng":ng})
#         EFG_results.append([PCS,PGS])
    
        
#         recipe = recipes3[i]
#         nsd = recipe[0]
#         n0 = recipe[1]
#         ng = recipe[2]
        
#         print("EFGPlus")
#         PCS, PGS = parallel_experiments(rng,  generators, policy=EFGPlus, remote_policy=remote_EFGPlus,  
#                                         args={"nsd":nsd, "n0":n0, "ng":ng, "G":G})

#         EFGPlus_results.append([PCS,PGS])
        
#         n = recipes4[i]
#         if n >= 81:
#             print("Modified Sequential Halving")
#             PCS, PGS = parallel_experiments(rng,  generators, policy=ModifiedSH, remote_policy=remote_ModifiedSH,  args={"n":n})
#             MoSH_results.append([PCS,PGS])

# %%
# problem_types = [(45,45)]
# seed = 20230118+45+45
# np.random.seed(seed)
# rng = np.random.default_rng(seed)


# for problem_type in problem_types:
#     slns, means = loadTPMax(problem_type[0], problem_type[1])
#     print("problem size:{}".format(len(slns)))
#     generators = [TpMaxGenerator(_njobs, _nstages, _burnin, slns, means, TpMaxSimulator) for i in range(n_replications)]
#     for i in range(n_recipe):
        
#         n = recipes0[i]
#         print("FBKT")
#         PCS, PGS = parallel_experiments(rng,  generators, policy=FBKT, remote_policy=remote_FBKT, 
#                                         args={"nsd":0, "n":n, "seeding":False})
#         FBKT_results.append([PCS,PGS])
        
#         recipe = recipes1[i]
#         nsd = recipe[0]
#         n0 = recipe[1]
        
#         print("FBKTSeeding")
#         PCS, PGS = parallel_experiments(rng,  generators, policy=FBKT, remote_policy=remote_FBKT, 
#                                         args={"nsd":nsd, "n": n0, "seeding":True})
#         FBKTS_results.append([PCS,PGS])
        
#         recipe = recipes2[i]
#         n0 = recipe[0]
#         ng = recipe[1]
        
#         print("EFG")
#         PCS, PGS = parallel_experiments(rng,  generators, policy=EFG, remote_policy=remote_EFG, 
#                                         args={"n0":n0, "ng":ng})
#         EFG_results.append([PCS,PGS])
    
        
#         recipe = recipes3[i]
#         nsd = recipe[0]
#         n0 = recipe[1]
#         ng = recipe[2]
        
#         print("EFGPlus")
#         PCS, PGS = parallel_experiments(rng,  generators, policy=EFGPlus, remote_policy=remote_EFGPlus,  
#                                         args={"nsd":nsd, "n0":n0, "ng":ng, "G":G})

#         EFGPlus_results.append([PCS,PGS])
        
#         n = recipes4[i]
#         if n >= 81:
#             print("Modified Sequential Halving")
#             PCS, PGS = parallel_experiments(rng,  generators, policy=ModifiedSH, remote_policy=remote_ModifiedSH,  args={"n":n})
#             MoSH_results.append([PCS,PGS])
